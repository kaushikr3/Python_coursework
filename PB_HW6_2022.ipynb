# %% [markdown]
# # Homework 6
# ## Statistical Analysis with Python
#
# ## Part 1
#
# In this assignment we will create two main functions: **getTtestPvalue** and **getLogRatio**
#
# The inputs of the functions will be
#
# - 1) Values from one gene
# - 2) Labels for the Values that assign the values to the different groups
#
# For example, the values below are from two groups, `a` and `b`. The first two values below to `a` and the last two belong to `b`.
#
# ```
# values = [1,2,3,4]
# groups = ['a','a','b','b']
# ```
#
# The output of the **getTtestPvalue** function will provide simply the p-value.
# The output of the **getLogRatio** function will provide the log2 of the fold change of the second group divided by the first group. In the example below it would be `b/a`.

# %% [markdown]
# ### 1. Load **expvalues.txt** load it into your environment and call it **expvalues**.

# %%
import pandas as pd
expvalues = pd.read_csv("expvalues.txt", sep=" ")
expvalues.head()
# Out:
#              Control1    Control2    Control3  Treatment1  Treatment2  \
# 244901_at  229.985654  353.599489  178.491707  112.908004  152.918347
# 244902_at  171.149796   84.450942   41.371951  170.172616  134.408135
# 244903_at  314.977684  373.312500   52.908731  196.302559  237.515204
# 244904_at   24.043665  175.316045   94.684235   82.784879   18.436387
# 244905_at   15.869235   40.041248   58.765734  341.353405   16.801354
#
#            Treatment3
# 244901_at  320.832347
# 244902_at  193.526115
# 244903_at  253.377736
# 244904_at   87.008573
# 244905_at   68.942039

# %% [markdown]
# ### 2. In this file the first three values are from a *control* experiment and the last three are from *treatment* experiment. Create a list that contains this information

# %%
factor = ["Control","Control","Control","Treatment","Treatment","Treatment"]
factor
# Out:
# ['Control', 'Control', 'Control', 'Treatment', 'Treatment', 'Treatment']

# %% [markdown]
# ### 3a. Provide the code for function **getTtestPvalue** in the cell below.

# %%
def getTtestPvalue(control_vals,trt_vals):
    from scipy.stats import ttest_ind
    tstat, pvalue = ttest_ind(control_vals,trt_vals)
    return(pvalue)

# %% [markdown]
# ### 3b. Execute the function on each row of **expvalues** and save all the pvalues in **ttestpvalues**.

# %%
from scipy.stats import ttest_ind
ttestpvalues = []
for rows in expvalues.iterrows():
   c_vals = rows[1][0:3]
   t_vals = rows[1][3:6]
   pvalue = getTtestPvalue(c_vals,t_vals)
   ttestpvalues.append(pvalue)

ttestpvalues
# Out:
# [0.5161536465998098,
#  0.18445628572917247,
#  0.8658765766816202,
#  0.5115301737648241,
#  0.36240928233770214,
#  0.280369838268712,
#  0.7513646459341939,
#  0.5895432108842638,
#  0.7875359802783938,
#  0.27219642782464465,
#  0.6510401324292445,
#  0.9140794600644173,
#  0.003656787299020637,
#  0.4752347826657845,
#  0.6698836335415557,
#  0.3879131802695455,
#  0.23474138506287004,
#  0.5816184955074215,
#  0.7686618178768968,
#  0.9408690107504338,
#  0.26931531185659874,
#  0.894322720971379,
#  0.8216426338922026,
#  0.5086804500017889,
#  0.03227870006454174,
#  0.7759993653453101,
#  0.6864803193535793,
#  0.6392035859011236,
#  0.9294298991072599,
#  0.47037575960065625,
#  0.5038972667224639,
#  0.19886830928681531,
#  0.5248364648525289,
#  0.9726684266575305,
#  0.3338659128162414,
#  0.33841002897352734,
#  0.30559550497139876,
#  0.6264586492097177,
#  0.32984381736018253,
#  0.10097771295104663,
#  0.8444324246913202,
#  0.617453154930157,
#  0.2040920474830547,
#  0.9031009289357942,
#  0.6566236287695923,
#  0.24373013240616365,
#  0.48182525014721933,
#  0.8392446435159114,
#  0.09165674721558806,
#  0.9317287473141598,
#  0.4185791263513705,
#  0.8065326494368502,
#  0.772460993630141,
#  0.24497414079820423,
#  0.9772256511262188,
#  0.7017740476459732,
#  0.8570252785134234,
#  0.07959530085204752,
#  0.04596666652519171,
#  0.06373896679411795,
#  0.7286876562036381,
#  0.6276317075790279,
#  0.8158874006563936,
#  0.854327951482659,
#  0.42640725471348173,
#  0.20036769685818606,
#  0.2934924557615923,
#  0.4880076976093377,
#  0.7650834030367666,
#  0.09055583619015659,
#  0.750502902916115,
#  0.15427938738252098,
#  0.27359074167998665,
#  0.7983308595896855,
#  0.0820443860046363,
#  0.9623479208290593,
#  0.6782039765958604,
#  0.7683640720945208,
#  0.17664515271919703,
#  0.08815128148064505,
#  0.802620934260108,
#  0.6611603988083474,
#  0.12468002908792457,
#  0.6711342790562596,
#  0.1601573749765229,
#  0.00011131820932481376,
#  0.9694615971001392,
#  0.9674304785468697,
#  0.7059632484291265,
#  0.1945013790540422,
#  0.8746772864466902,
#  0.062317746763403695,
#  0.41041877238390706,
#  0.6236820586056602,
#  0.854123229509931,
#  0.3364652075160465,
#  0.7655333839675997,
#  0.3801872332531789,
#  0.47022317639346084,
#  0.27346231714566216,
#  0.4001334252817018,
#  0.9034480692521369,
#  0.5622541789796835,
#  0.6144735881995891,
#  0.8061675035936959,
#  0.576016637376954,
#  0.4095174233794812,
#  0.31004237883826935,
#  0.4007687256862032,
#  0.23764570880903843,
#  0.33109567493435177,
#  0.7037521658220227,
#  0.4474898179106494,
#  0.6007098753135687,
#  0.16838907217012275,
#  0.44710747223571545,
#  0.5384909499370455,
#  0.48638836220431714,
#  0.8722744942424913,
#  ...]

# %% [markdown]
# ### 4a. Provide the code for function **getLogRatio** in the cell below.

# %%
def getLogRatio(A, B):
    import numpy as np
    # calculate the log ratio of A to B
    logRatio = np.log2(B/A)
    return(logRatio)

# %%
import numpy as np
for rows in expvalues.iterrows():
    print(np.log2(rows[1][3:6]/rows[1][0:3]))

# %% [markdown]
# ### 4b. Execute the function on each row of **expvalues** and save all the log fold change in **lfc**.

# %%
# initialize an empty list to store the log fold changes
lfc = []

# loop through each row in expvalues
for rows in expvalues.iterrows():
   c_vals = rows[1][0:3]
   t_vals = rows[1][3:6]
   logratio = getLogRatio(c_vals,t_vals)
   lfc.append(logratio)

lfc
# Out:
# [Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244901_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244902_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244903_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244904_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244905_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244906_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244907_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244908_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244909_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244910_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244911_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244912_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244913_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244914_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244915_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244916_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244917_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244918_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244919_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244920_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244921_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244922_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244923_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244924_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244925_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244926_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244927_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244928_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244929_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244930_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244931_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244932_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244933_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244934_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244935_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244936_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244937_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 244938_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 
at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245863_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245864_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245865_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245866_s_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245867_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245868_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245869_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245870_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245871_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245872_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245873_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245874_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245875_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245876_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245877_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245878_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245879_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245880_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245881_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245882_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245883_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245884_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245885_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245886_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245887_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245888_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245889_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245890_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245891_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245892_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245893_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245894_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245895_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245896_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245897_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245898_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245899_at, dtype: float64,
#  Control1     NaN
#  Control2     NaN
#  Control3     NaN
#  Treatment1   NaN
#  Treatment2   NaN
#  Treatment3   NaN
#  Name: 245900_at, dtype: float64,
#  ...]

# %% [markdown]
# ### 5. Use  **statsmodels.stats.multitest.fdrcorrection** to correct for multiple hypothesis testing and save the adjusted p-values as **padj**. You will have to look at the documentation of the function and learn how to use it.

# %%
from statsmodels.stats.multitest import fdrcorrection as fdr
padj = fdr(pvals=ttestpvalues,method="i")

# %% [markdown]
# ## Part 2: Clustering
#
# ### 6. Another file, called **random_genes.txt**, contains 616 gene ids. Create a new dataframe which is a subset of **expvalues** containing just the values for the 616 genes in the list. Call it **random_values**.

# %%
import pandas as pd
random_genes = pd.read_csv("random_genes.txt",header=None)
random_genes.head()
# Out:
#            0
# 0  245112_at
# 1  245117_at
# 2  245126_at
# 3  245139_at
# 4  245148_at

# %%
random_values = expvalues.loc[random_genes[0]]

# %% [markdown]
# ### 7. Perform a pairwise pearson correlation for all genes in **random_values**. Save this as **random_values_cor**

# %%
random_values_cor = np.corrcoef(random_values)

# %% [markdown]
# ### 8. Perform a hierarchical clustering using the **scipy.cluster.hierachy**. Ask for 2 groups. How many genes in each group?

# %%
import scipy.cluster.hierarchy as hc
expdist = 1 - random_values_cor
Zcor = hc.linkage(expdist, 'average')

dZcor = hc.dendrogram(Zcor)
groups = hc.cut_tree(Zcor, n_clusters=2)
# Out:
# /var/folders/j7/9_rj6z3d0lb_bf3zmvnw7t_h0000gn/T/ipykernel_87745/66681006.py:3: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Zcor = hc.linkage(expdist, 'average')

# %%
group0 = random_values[groups==0]
group1 = random_values[groups==1]

# %%
group0.shape
# Out:
# (274, 6)

# %%
group1.shape
# Out:
# (342, 6)

# %% [markdown]
# There are 274 genes in group 1 and 342 genes in group 2

# %% [markdown]
# ### 9. Perform K-means clustering using **scipy.cluster.vq.kmeans**. Check out the documentation here: [https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.vq.kmeans.html#scipy.cluster.vq.kmeans](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.vq.kmeans.html#scipy.cluster.vq.kmeans)
#
# Use K = 2. How many genes are there in each group?

# %%
from scipy.cluster.vq import vq, kmeans2, whiten

# %%
centroid, label = kmeans2(random_values, 2)
counts = np.bincount(label)
counts
# Out:
# array([547,  69])

# %% [markdown]
# Group 1 has 547 genes whereas group 2 has only 69 genes

# %% [markdown]
# ### 10. Compare the clusters from hierarchical clustering with kmeans clustering by counting the number of genes they share. Are the results the same or different?

# %% [markdown]
# The results are very different to each other because, heirarchical clustering uses correlation distance whereas kmeans uses euclidean distance to a centroid. In this case heirarchical clustering resulted in equally divided groups with 274 and 342 genes respectively whereas kmeans resulted in 1 huge grooup and one small group with 547 and 69 genes respectively.
